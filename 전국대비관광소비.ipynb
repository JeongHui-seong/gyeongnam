# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import matplotlib.ticker as ticker
import numpy as np
import matplotlib.dates as mdates

# %%
fm.fontManager.addfont(path = "./font/NanumGothic.ttf")
matplotlib.rcParams["font.family"] = "NanumGothic"

# %%
df = pd.read_csv("./csv/202310202503전국대비관광소비.csv")

# %%
df
# Out:
#       기준연월   지역명  관광소비액(백만원)  전국 관광소비액(백만원)  전국 대비 관광소비율
# 0   202310  경상남도      142735        3672830          3.9
# 1   202311  경상남도      125443        3352999          3.7
# 2   202312  경상남도      129557        3565655          3.6
# 3   202401  경상남도      115631        3070452          3.8
# 4   202402  경상남도      117478        3028104          3.9
# 5   202403  경상남도      131907        3480463          3.8
# 6   202404  경상남도      127858        3370064          3.8
# 7   202405  경상남도      138010        3564908          3.9
# 8   202406  경상남도      128114        3392003          3.8
# 9   202407  경상남도      125115        3271115          3.8
# 10  202408  경상남도      134713        3431813          3.9
# 11  202409  경상남도      126106        3254116          3.9
# 12  202410  경상남도      132273        3409220          3.9
# 13  202411  경상남도      126135        3264109          3.9
# 14  202412  경상남도      119534        3256769          3.7
# ...

# %%
x = np.arange(len(df['기준연월']))

fig, ax1 = plt.subplots(1, 1, figsize = (18, 8))

bar1 = ax1.bar(x - 0.2, df['전국 관광소비액(백만원)'], width = 0.4, label = '전국', color = 'lightgray')
ax1.set_ylabel('전국 관광소비액(백만원)', color = 'black')
ax1.tick_params(axis = 'y', labelcolor = 'black')
ax1.set_xticks(x)
ax1.set_xticklabels(df['기준연월'])
ax1.yaxis.set_major_formatter(ticker.ScalarFormatter(useOffset = False))
ax1.ticklabel_format(style = 'plain', axis = 'y')

ax2 = ax1.twinx()
bar2 = ax2.bar(x + 0.2, df['관광소비액(백만원)'], width = 0.4, label = '경상남도', color = 'green')
ax2.set_ylabel('경상남도 관광소비액(백만원)', color = 'green')
ax2.tick_params(axis = 'y', labelcolor = 'green')

fig.legend(loc = 'upper left', bbox_to_anchor = (0.85, 0.93))
plt.title('전국대비 관광소비액 비교')
plt.tight_layout()
plt.savefig("./img/전국대비관광소비액비교.png")
plt.show()

# %%
plt.figure(figsize = (18, 12))

df['기준연월'] = pd.to_datetime(df['기준연월'].astype(int).astype(str), format = '%Y%m')
# print(df['기준연월'])

plt.plot(df['기준연월'],df['전국 대비 관광소비율'], marker = 'o')
plt.title('전국 대비 경상남도 관광소비율 추이')
plt.xlabel("기준연월")
plt.ylabel("소비 비율(%)")

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.grid(True, alpha = 0.5)
plt.tight_layout()
plt.savefig('./img/전국대비경상남도관광소비율추이.png')
plt.show()
